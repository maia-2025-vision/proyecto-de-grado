# %%
import os
import sys
from pathlib import Path

import boto3
import pandas as pd
import requests
from mypy_boto3_s3 import S3Client

os.chdir("/Users/mrestrepo/git/_personal/proyecto-de-grado")

bucket = "cow-detect-maia"

key_pattern = "{region}/{flyover}/{file_name}"
local_base = Path("data/patches-512-ol-160-m01/train")
sample_size = 20
API_BASE_URL = "http://localhost:8000"

# %%
df = pd.read_csv("data/patches-512-ol-160-m01/train_points_gt.csv")

by_img = (
    df.groupby(["images", "labels"])
    .agg({"x": "count"})
    .rename(columns={"x": "count"})
    .sort_values("count", ascending=False)
)
by_img = by_img[by_img["count"] > 5]
by_img.shape
# Out:
# (325, 1)

# %%
by_img
# Out:
#                                                          count
# images                                           labels
# L_09_05_16_DSC10034_95.JPG                       2          22
# L_09_05_16_DSC10034_96.JPG                       2          22
# L_07_05_16_DSC00414_33.JPG                       2          22
# L_11_05_16_DSC01346_104.JPG                      2          20
# L_11_05_16_DSC01346_103.JPG                      2          19
# ...                                                        ...
# 0af7b1ea3a107e511353adbaba10c2e55a0bddf2_132.JPG 6           6
# L_07_05_16_DSC00647_130.JPG                      1           6
# L_09_05_16_DSC10176_86.JPG                       2           6
# S_10_05_16_DSC00824_17.JPG                       2           6
# 194d47b881a73d5473f78faa573878f013afd3c5_133.JPG 6           6
#
# [325 rows x 1 columns]

# %%
session = boto3.Session(region_name="us-east-1", profile_name="dvc-user")
s3: S3Client = session.client("s3")

# %%
by_img.sample(sample_size)
# Out:
#                                                          count
# images                                           labels
# L_07_05_16_DSC00414_50.JPG                       2          10
# L_07_05_16_DSC00646_11.JPG                       1           7
# L_11_05_16_DSC01397_28.JPG                       3           8
# 192c864e5739ae7f51bd00a54598e38139405e7f_147.JPG 6          11
# 0bcb68603f1d04e6da66bac87e722b61cb2b6b69_95.JPG  6          10
# 045498edab1c4c373cb7eff56cdc4f57ab75e772_5.JPG   6           6
# 0df8cbe13350f5b20d9d4156577709895c315e85_8.JPG   6           6
# L_11_05_16_DSC01346_104.JPG                      2          20
# 272c2cae1374216920ef579815b1277c9b59f3f1_33.JPG  6           7
# 0df8cbe13350f5b20d9d4156577709895c315e85_24.JPG  6           8
# L_07_05_16_DSC00646_26.JPG                       1           6
# L_09_05_16_DSC10151_72.JPG                       3           6
# 1a30f61c368dfcb2010da94ab84c0c734376f7fd_84.JPG  6          14
# L_11_05_16_DSC01386_83.JPG                       1           7
# L_09_05_16_DSC10034_78.JPG                       2          11
# L_11_05_16_DSC01346_87.JPG                       2          15
# 194d47b881a73d5473f78faa573878f013afd3c5_117.JPG 6           6
# 12f0439da7755b0d290277a12dfea4ce68fb5d2e_140.JPG 6           6
# L_11_05_16_DSC01346_171.JPG                      2           8
# 0bcb68603f1d04e6da66bac87e722b61cb2b6b69_78.JPG  6           7

# %%
import numpy as np

resp = requests.get(f"{API_BASE_URL}/app-info")
model_name = resp.json()["model_info"]["model_metadata"]["name"]
print(f"{model_name=}")
region = {"HerdNet": "Chad-HN", "FasterRCNNResNetFPN": "Chad-FRC"}[model_name]
print(f"{region=}")
np.random.seed(42)
for flyover in ["2025-06-30", "2025-07-31", "2025-08-31", "2025-09-30", "2025-10-31"]:
    sample = by_img.sample(sample_size).reset_index()
    for _, row in sample.iterrows():
        file_name = row["images"]
        print(f"{flyover=}, {file_name=}")
        key = key_pattern.format(region=region, flyover=flyover, file_name=row["images"])

        s3.upload_file(local_base / file_name, bucket, key)

        payload = {"s3_path": f"s3://{bucket}/{key}"}
        resp = requests.post(f"{API_BASE_URL}/predict", json=payload)
        print(resp.status_code)
# Out:
# model_name='HerdNet'
# region='Chad-HN'
# flyover='2025-06-30', file_name='079557329c366472fd970ee021e37abe2e44c7ca_34.JPG'
# 200
# flyover='2025-06-30', file_name='S_10_05_16_DSC00472_171.JPG'
# 200
# flyover='2025-06-30', file_name='S_09_05_16_DSC00412_25.JPG'
# 200
# flyover='2025-06-30', file_name='L_09_05_16_DSC10034_76.JPG'
# 200
# flyover='2025-06-30', file_name='146396c157f95fd6b6c113e5118e97546d69a431_72.JPG'
# 200
# flyover='2025-06-30', file_name='0fd5ba32f00698a140e080008c2af81b2ae9fa5c_152.JPG'
# 200
# flyover='2025-06-30', file_name='026ae7f5cddac223d6e364b7c16779b271cb3198_144.JPG'
# 200
# flyover='2025-06-30', file_name='09e1e0ddb23a9c3e5ac62b552a856111b5f11942_119.JPG'
# 200
# flyover='2025-06-30', file_name='L_11_05_16_DSC01386_100.JPG'
# 200
# flyover='2025-06-30', file_name='L_09_05_16_DSC10034_24.JPG'
# 200
# flyover='2025-06-30', file_name='14aa6dc307cfb871cedebf75bf6d7ec6df7a2c00_21.JPG'
# 200
# flyover='2025-06-30', file_name='S_10_05_16_DSC00472_157.JPG'
# 200
# flyover='2025-06-30', file_name='00f062e946ccdb29a71c0c0f410ff6e2add728ad_91.JPG'
# 200
# flyover='2025-06-30', file_name='L_11_05_16_DSC01397_28.JPG'
# 200
# flyover='2025-06-30', file_name='0af7b1ea3a107e511353adbaba10c2e55a0bddf2_132.JPG'
# 200
# flyover='2025-06-30', file_name='L_09_05_16_DSC10034_68.JPG'
# 200
# flyover='2025-06-30', file_name='0df8cbe13350f5b20d9d4156577709895c315e85_25.JPG'
# 200
# flyover='2025-06-30', file_name='L_07_05_16_DSC00744_68.JPG'
# 200
# flyover='2025-06-30', file_name='L_09_05_16_DSC10034_23.JPG'
# 200
# flyover='2025-06-30', file_name='03c04daf5ae49a9434d9ca5928d2aa456168b0cd_121.JPG'
# 200
# flyover='2025-07-31', file_name='0bcb68603f1d04e6da66bac87e722b61cb2b6b69_95.JPG'
# 200
# flyover='2025-07-31', file_name='12f0439da7755b0d290277a12dfea4ce68fb5d2e_125.JPG'
# 200
# flyover='2025-07-31', file_name='260785d385da8fd3315a6e3303586886a0b3871b_32.JPG'
# 200
# flyover='2025-07-31', file_name='S_09_05_16_DSC00413_128.JPG'
# 200
# flyover='2025-07-31', file_name='09e1e0ddb23a9c3e5ac62b552a856111b5f11942_152.JPG'
# 200
# flyover='2025-07-31', file_name='12e86d159585a19fc5853227e67ffe4f5aef3c21_85.JPG'
# 200
# flyover='2025-07-31', file_name='L_11_05_16_DSC01144_162.JPG'
# 200
# flyover='2025-07-31', file_name='220a276f8e6fa93834f053cfe9b1c8186f43feb0_85.JPG'
# 200
# flyover='2025-07-31', file_name='2e7062cf15f728e4657b3a92eeeb8838cbf78118_13.JPG'
# 200
# flyover='2025-07-31', file_name='19be3a6ae4c31cdf6c11fa1ae7a8451c649f6f5e_154.JPG'
# 200
# flyover='2025-07-31', file_name='L_11_05_16_DSC01143_21.JPG'
# 200
# flyover='2025-07-31', file_name='0660f13c6db5a9666415437addfdf6a9535e0453_12.JPG'
# 200
# flyover='2025-07-31', file_name='146396c157f95fd6b6c113e5118e97546d69a431_68.JPG'
# 200
# flyover='2025-07-31', file_name='194d47b881a73d5473f78faa573878f013afd3c5_133.JPG'
# 200
# flyover='2025-07-31', file_name='S_09_05_16_DSC00459_153.JPG'
# 200
# flyover='2025-07-31', file_name='L_09_05_16_DSC10035_142.JPG'
# 200
# flyover='2025-07-31', file_name='L_07_05_16_DSC00414_16.JPG'
# 200
# flyover='2025-07-31', file_name='19b44dead52d80fabeb431d55952b1c3f6108a2e_119.JPG'
# 200
# flyover='2025-07-31', file_name='06d5ce33b84af693cd25a468c6ede67c44ffab8b_129.JPG'
# 200
# flyover='2025-07-31', file_name='1c14b31897595ab63a3209b41c17faa987d98cd0_87.JPG'
# 200
# flyover='2025-08-31', file_name='L_09_05_16_DSC10139_103.JPG'
# 200
# flyover='2025-08-31', file_name='L_09_05_16_DSC10150_106.JPG'
# 200
# flyover='2025-08-31', file_name='06814f3eed89cbc6c3e36d695a6326c8edab634c_122.JPG'
# 200
# flyover='2025-08-31', file_name='L_11_05_16_DSC01397_28.JPG'
# 200
# flyover='2025-08-31', file_name='L_11_05_16_DSC01346_4.JPG'
# 200
# flyover='2025-08-31', file_name='L_07_05_16_DSC00414_50.JPG'
# 200
# flyover='2025-08-31', file_name='01de5b7225fc89e56d57ae1e14cd945cb67f5a0e_116.JPG'
# 200
# flyover='2025-08-31', file_name='L_11_05_16_DSC01059_145.JPG'
# 200
# flyover='2025-08-31', file_name='0f5e855972a22b049ca564b99727c5c3900dba4d_8.JPG'
# 200
# flyover='2025-08-31', file_name='0af7b1ea3a107e511353adbaba10c2e55a0bddf2_132.JPG'
# 200
# flyover='2025-08-31', file_name='1f2b5a52ee1fb08e508bd9db013802077fa3de8c_33.JPG'
# 200
# flyover='2025-08-31', file_name='1f6b224acdc6290871330683732392a082ca062c_124.JPG'
# 200
# flyover='2025-08-31', file_name='L_11_05_16_DSC01346_138.JPG'
# 200
# flyover='2025-08-31', file_name='L_11_05_16_DSC01346_85.JPG'
# 200
# flyover='2025-08-31', file_name='220a276f8e6fa93834f053cfe9b1c8186f43feb0_39.JPG'
# 200
# flyover='2025-08-31', file_name='S_10_05_16_DSC00471_70.JPG'
# 200
# flyover='2025-08-31', file_name='2521fa11a61c54af332779776fea94d990ef2711_100.JPG'
# 200
# flyover='2025-08-31', file_name='L_11_05_16_DSC01346_137.JPG'
# 200
# flyover='2025-08-31', file_name='S_09_05_16_DSC00413_114.JPG'
# 200
# flyover='2025-08-31', file_name='26f3bf698262dc714f8c044ee59309a36f961d7d_98.JPG'
# 200
# flyover='2025-09-30', file_name='L_11_05_16_DSC01346_155.JPG'
# 200
# flyover='2025-09-30', file_name='L_07_05_16_DSC00414_33.JPG'
# 200
# flyover='2025-09-30', file_name='2abd4798bf4ce5583adc163a59376ec86ad4911b_66.JPG'
# 200
# flyover='2025-09-30', file_name='1a30f61c368dfcb2010da94ab84c0c734376f7fd_52.JPG'
# 200
# flyover='2025-09-30', file_name='L_11_05_16_DSC01109_77.JPG'
# 200
# flyover='2025-09-30', file_name='1d3e6c5daa4a821915ffd11f8a917efaf2ddc986_12.JPG'
# 200
# flyover='2025-09-30', file_name='06932f783fc99926b9e25d5136a03679655af3b8_37.JPG'
# 200
# flyover='2025-09-30', file_name='L_09_05_16_DSC10177_52.JPG'
# 200
# flyover='2025-09-30', file_name='2e7062cf15f728e4657b3a92eeeb8838cbf78118_13.JPG'
# 200
# flyover='2025-09-30', file_name='09e1e0ddb23a9c3e5ac62b552a856111b5f11942_136.JPG'
# 200
# flyover='2025-09-30', file_name='L_07_05_16_DSC00414_32.JPG'
# 200
# flyover='2025-09-30', file_name='0df8cbe13350f5b20d9d4156577709895c315e85_8.JPG'
# 200
# flyover='2025-09-30', file_name='12e86d159585a19fc5853227e67ffe4f5aef3c21_85.JPG'
# 200
# flyover='2025-09-30', file_name='L_11_05_16_DSC01397_47.JPG'
# 200
# flyover='2025-09-30', file_name='1df6426b66436c4e4aefa1cb683e5e0f764941c8_121.JPG'
# 200
# flyover='2025-09-30', file_name='1df6426b66436c4e4aefa1cb683e5e0f764941c8_137.JPG'
# 200
# flyover='2025-09-30', file_name='L_09_05_16_DSC10034_148.JPG'
# 200
# flyover='2025-09-30', file_name='L_11_05_16_DSC01346_138.JPG'
# 200
# flyover='2025-09-30', file_name='1119d743dbe7217d0a6ff2730ec06228032965e4_120.JPG'
# 200
# flyover='2025-09-30', file_name='S_10_05_16_DSC00471_53.JPG'
# 200
# flyover='2025-10-31', file_name='146396c157f95fd6b6c113e5118e97546d69a431_67.JPG'
# 200
# flyover='2025-10-31', file_name='L_07_05_16_DSC00646_26.JPG'
# 200
# flyover='2025-10-31', file_name='L_09_05_16_DSC10034_95.JPG'
# 200
# flyover='2025-10-31', file_name='L_10_05_16_DSC01571_115.JPG'
# 200
# flyover='2025-10-31', file_name='12464acd2863fd3abb6af3f0d120e7fec03270e0_115.JPG'
# 200
# flyover='2025-10-31', file_name='S_09_05_16_DSC00413_114.JPG'
# 200
# flyover='2025-10-31', file_name='272c2cae1374216920ef579815b1277c9b59f3f1_33.JPG'
# 200
# flyover='2025-10-31', file_name='L_09_05_16_DSC10149_21.JPG'
# 200
# flyover='2025-10-31', file_name='S_09_05_16_DSC00834_18.JPG'
# 200
# flyover='2025-10-31', file_name='L_11_05_16_DSC01109_77.JPG'
# 200
# flyover='2025-10-31', file_name='S_09_05_16_DSC00413_115.JPG'
# 200
# flyover='2025-10-31', file_name='0bcb68603f1d04e6da66bac87e722b61cb2b6b69_94.JPG'
# 200
# flyover='2025-10-31', file_name='L_09_05_16_DSC10149_3.JPG'
# 200
# flyover='2025-10-31', file_name='L_09_05_16_DSC10035_159.JPG'
# 200
# flyover='2025-10-31', file_name='2abd4798bf4ce5583adc163a59376ec86ad4911b_84.JPG'
# 200
# flyover='2025-10-31', file_name='2ddc7715c7aba737c2bb3a7f1da76953a5f6487b_53.JPG'
# 200
# flyover='2025-10-31', file_name='06814f3eed89cbc6c3e36d695a6326c8edab634c_139.JPG'
# 200
# flyover='2025-10-31', file_name='L_09_05_16_DSC10034_41.JPG'
# 200
# flyover='2025-10-31', file_name='288c27817e314ea6ce7b40f9bc3db17ad22535ba_107.JPG'
# 200
# flyover='2025-10-31', file_name='S_10_05_16_DSC00824_35.JPG'
# 200
